# %%
# Question 1 - Extracting Tesla Stock Data Using yfinance
# !pip install matplotlip
import yfinance as yf
import pandas as pd

# %%
tesla = yf.Ticker("TSLA")
print(tesla)
# Out:
# yfinance.Ticker object <TSLA>

# %%
tsla_stock = tesla.history(period='max')
tsla_stock
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2024-12-20 00:00:00-05:00  425.510010  447.079987  417.640015  421.059998
# 2024-12-23 00:00:00-05:00  431.000000  434.510010  415.410004  430.600006
# 2024-12-24 00:00:00-05:00  435.899994  462.779999  435.140015  462.279999
# 2024-12-26 00:00:00-05:00  465.160004  465.329987  451.019989  454.130005
# 2024-12-27 00:00:00-05:00  449.519989  450.000000  426.500000  431.660004
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
tsla_stock.reset_index(inplace=True)
tsla_stock.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
# Question 2 - Extracting Tesla Revenue Data Using Webscraping
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
tsla_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
tsla_revenue_data = pd.read_html(tsla_url)[1]
tsla_revenue_data.columns = ["Date", "Revenue"]
tsla_revenue_data["Revenue"].replace(to_replace=r',|\$', value='', inplace=True, regex=True)
tsla_revenue_data.dropna(inplace=True)
tsla_revenue_data = tsla_revenue_data[tsla_revenue_data['Revenue'] != ""]
tsla_revenue_data.tail()
# Out:
#           Date Revenue
# 48  2010-09-30      31
# 49  2010-06-30      28
# 50  2010-03-31      21
# 52  2009-09-30      46
# 53  2009-06-30      27

# %%
# Question 3 - Extracting GameStop Stock Data Using yfinance
GME = yf.Ticker("GME")
GME_stock = GME.history(period='max')
GME_stock
GME_stock.reset_index(inplace=True)
GME_stock
# Out:
#                           Date       Open       High        Low      Close  \
# 0    2002-02-13 00:00:00-05:00   1.620128   1.693350   1.603296   1.691666
# 1    2002-02-14 00:00:00-05:00   1.712707   1.716074   1.670626   1.683250
# 2    2002-02-15 00:00:00-05:00   1.683250   1.687458   1.658002   1.674834
# 3    2002-02-19 00:00:00-05:00   1.666417   1.666417   1.578047   1.607504
# 4    2002-02-20 00:00:00-05:00   1.615920   1.662210   1.603296   1.662210
# ...                        ...        ...        ...        ...        ...
# 5753 2024-12-20 00:00:00-05:00  28.540001  30.520000  28.309999  29.820000
# 5754 2024-12-23 00:00:00-05:00  29.820000  31.110001  29.780001  30.900000
# 5755 2024-12-24 00:00:00-05:00  31.000000  31.590000  30.580000  31.139999
# 5756 2024-12-26 00:00:00-05:00  32.619999  34.369999  31.600000  32.990002
# 5757 2024-12-27 00:00:00-05:00  32.389999  33.049999  30.730000  32.200001
#
#         Volume  Dividends  Stock Splits
# ...

# %%
# Question 4 - Extracting GameStop Revenue Data Using Webscraping 
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
gme_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html"
html_data = requests.get(gme_url).text
gme_revenue_data = pd.read_html(gme_url)[1]
gme_revenue_data.columns = ["Date", "Revenue"]
gme_revenue_data["Revenue"].replace(to_replace=r',|\$', value='', inplace=True, regex=True)
gme_revenue_data.dropna(inplace=True)
gme_revenue_data = gme_revenue_data[gme_revenue_data['Revenue'] != ""]
gme_revenue_data.tail()
# Out:
#           Date Revenue
# 57  2006-01-31    1667
# 58  2005-10-31     534
# 59  2005-07-31     416
# 60  2005-04-30     475
# 61  2005-01-31     709

# %%
# Question 6 - GameStop Stock and Revenue Dashboard
import matplotlib.pyplot as plt
def make_graph(stock_data, title="GME Stock", x_label="Time", y_label="stock"):
    plt.figure(figsize=(10, 6))
    plt.plot(stock_data, marker="")
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.grid(True)
    plt.show()
make_graph(GME_stock["Close"])

# %%
# Question 5 - Tesla Stock and Revenue Dashboard
import matplotlib.pyplot as plt
def make_graph(stock_data, title="Tesla Stock", x_label="Time", y_label="stock"):
    plt.figure(figsize=(10, 6))
    plt.plot(stock_data, marker="")
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.grid(True)
    plt.show()
make_graph(tsla_stock["Close"])
